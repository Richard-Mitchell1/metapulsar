# %% [markdown]
# # MetaPulsar Enterprise Integration Tutorial
#
# This notebook demonstrates how to integrate MetaPulsar with the Enterprise framework for gravitational wave analysis.
#
# ## Learning Objectives
# - Understand Enterprise integration concepts
# - Learn how to use staggered selection utilities
# - Explore MetaPulsar data preparation for Enterprise
# - Handle Enterprise-specific data requirements

# %%
from metapulsar import FileDiscoveryService, MetaPulsarFactory, create_staggered_selection

from loguru import logger

# Set global loguru level
logger.remove()
logger.add(lambda msg: print(msg, end=""), level="WARNING")


print("MetaPulsar Enterprise Integration imported successfully!")
# Out:
# /opt/venvs/pta/lib/python3.10/site-packages/enterprise/signals/utils.py:13: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import Requirement, resource_filename
# MetaPulsar Enterprise Integration imported successfully!

# %% [markdown]
# ## 1. Prepare MetaPulsar Data
#
# First, let's create MetaPulsar data that can be used with Enterprise.

# %%
# Create file discovery service with working directory
# Note: We need to specify the working directory because the notebook runs from
# /workspaces/metapulsar/examples/notebooks/ but the data is in /workspaces/metapulsar/data/
discovery = FileDiscoveryService(working_dir="/workspaces/metapulsar")

# Discover files for specific PTAs
# Note: Using available PTAs that have data
pta_names = ["epta_dr1_v2_2", "ppta_dr2", "nanograv_9y"]
file_data = discovery.discover_all_files_in_ptas(pta_names)

print("File discovery results:")
for pta_name, files in file_data.items():
    print(f"  {pta_name}: {len(files)} file pairs")
# Out:
# 2025-10-06 13:40:40.512 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J0034-0534/J0034-0534_all.tim: invalid literal for int() with base 10: 'TOAS'
# 2025-10-06 13:40:40.517 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J0218+4232/J0218+4232_all.tim: invalid literal for int() with base 10: '0 55058'
# 2025-10-06 13:40:40.519 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J0610-2100/J0610-2100_all.tim: invalid literal for int() with base 10: '0 55372'
# 2025-10-06 13:40:40.527 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J0613-0200/J0613-0200_all.tim: invalid literal for int() with base 10: '0 55054'
# 2025-10-06 13:40:40.533 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J0621+1002/J0621+1002_all.tim: invalid literal for int() with base 10: '0 55062'
# 2025-10-06 13:40:40.540 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J0751+1807/J0751+1807_all.tim: invalid literal for int() with base 10: '0 55054'
# 2025-10-06 13:40:40.545 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J0900-3144/J0900-3144_all.tim: invalid literal for int() with base 10: '0 55073'
# 2025-10-06 13:40:40.551 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1012+5307/J1012+5307_all.tim: invalid literal for int() with base 10: '0 55122'
# 2025-10-06 13:40:40.561 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1022+1001/J1022+1001_all.tim: invalid literal for int() with base 10: '0 55065'
# 2025-10-06 13:40:40.572 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1024-0719/J1024-0719_all.tim: invalid literal for int() with base 10: '0 55059'
# 2025-10-06 13:40:40.574 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1455-3330/J1455-3330_all.tim: invalid literal for int() with base 10: '0 55114'
# 2025-10-06 13:40:40.689 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1640+2224/J1640+2224_all.tim: invalid literal for int() with base 10: '0 55057'
# 2025-10-06 13:40:40.695 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1643-1224/J1643-1224_all.tim: invalid literal for int() with base 10: '0 55069'
# 2025-10-06 13:40:40.992 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1730-2304/J1730-2304_all.tim: invalid literal for int() with base 10: '0 55073'
# 2025-10-06 13:40:41.042 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1738+0333/J1738+0333_all.tim: list index out of range
# 2025-10-06 13:40:41.071 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1744-1134/J1744-1134_all.tim: could not convert string to float: 'c015621.align.pazr.30min'
# 2025-10-06 13:40:41.148 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1801-1417/J1801-1417_all.tim: invalid literal for int() with base 10: '0 55074'
# 2025-10-06 13:40:41.265 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1804-2717/J1804-2717_all.tim: invalid literal for int() with base 10: '0 54854'
# 2025-10-06 13:40:41.303 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1843-1113/J1843-1113_all.tim: invalid literal for int() with base 10: '0 55059'
# 2025-10-06 13:40:41.306 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1853+1303/J1853+1303_all.tim: invalid literal for int() with base 10: '0 55066'
# 2025-10-06 13:40:41.508 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1910+1256/J1910+1256_all.tim: invalid literal for int() with base 10: '0 54868'
# 2025-10-06 13:40:41.527 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1911+1347/J1911+1347_all.tim: list index out of range
# 2025-10-06 13:40:41.566 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1918-0642/J1918-0642_all.tim: invalid literal for int() with base 10: '0 55048'
# 2025-10-06 13:40:41.614 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1939+2134/J1939+2134_all.tim: could not convert string to float: 'c028084.pazr.iter.30min'
# 2025-10-06 13:40:41.659 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J2010-1323/J2010-1323_all.tim: invalid literal for int() with base 10: '0 55060'
# 2025-10-06 13:40:41.661 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J2019+2425/J2019+2425_all.tim: invalid literal for int() with base 10: '0 55053'
# 2025-10-06 13:40:41.667 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J2033+1734/J2033+1734_all.tim: invalid literal for int() with base 10: '0 55059'
# 2025-10-06 13:40:41.793 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J2145-0750/J2145-0750_all.tim: invalid literal for int() with base 10: '0 55037'
# 2025-10-06 13:40:41.799 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J2229+2643/J2229+2643_all.tim: invalid literal for int() with base 10: '0 55063'
# 2025-10-06 13:40:41.804 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J2317+1439/J2317+1439_all.tim: invalid literal for int() with base 10: '0 55056'
# 2025-10-06 13:40:41.810 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J2322+2057/J2322+2057_all.tim: invalid literal for int() with base 10: '0 55065'
# File discovery results:
#   epta_dr1_v2_2: 42 file pairs
#   ppta_dr2: 18 file pairs
#   nanograv_9y: 37 file pairs

# %%
# Filter out PTAs with no files and group results
file_data_with_files = {pta: files for pta, files in file_data.items() if files}

factory = MetaPulsarFactory()

# Group files by pulsar
pulsar_groups = factory.group_files_by_pulsar(file_data_with_files)

print(f"Found {len(pulsar_groups)} pulsars: {list(pulsar_groups.keys())}")
# Out:
# /opt/venvs/pta/lib/python3.10/site-packages/pint/models/model_builder.py:225: UserWarning: Unrecognized parfile line 'EPHVER 5'
#   warnings.warn(f"Unrecognized parfile line '{p_line}'", UserWarning)
# 2025-10-06 13:41:23.807 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:41:23.810 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:41:27.206 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: ELL1.
# 2025-10-06 13:41:27.212 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:41:27.214 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:41:30.594 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: ELL1.
# 2025-10-06 13:41:30.602 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:41:30.604 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:41:33.991 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: ELL1.
# 2025-10-06 13:41:33.997 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:41:33.999 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:41:37.387 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: ELL1.
# 2025-10-06 13:41:37.395 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:41:37.397 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:41:40.823 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: BT.
# 2025-10-06 13:41:40.830 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:41:40.831 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:41:44.217 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: ELL1H.
# 2025-10-06 13:41:44.226 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:41:44.228 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:41:47.619 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: ELL1.
# 2025-10-06 13:41:47.626 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:41:47.628 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:41:51.037 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: ELL1.
# 2025-10-06 13:41:51.046 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:41:51.048 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:41:54.488 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:41:54.490 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:41:57.901 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:41:57.903 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:01.291 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: BT.
# 2025-10-06 13:42:01.296 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:01.299 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:04.691 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:04.693 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:08.106 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: BT.
# 2025-10-06 13:42:08.113 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:08.115 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:11.553 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: BT.
# 2025-10-06 13:42:11.560 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:11.562 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:15.017 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: DDK.
# 2025-10-06 13:42:15.025 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:15.027 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# /opt/venvs/pta/lib/python3.10/site-packages/pint/models/stand_alone_psr_binaries/DDK_model.py:145: UserWarning: DDK model uses KIN as inclination angle. SINI will not be used. This happens every time a DDK model is constructed.
#   warnings.warn(
# 2025-10-06 13:42:18.512 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:18.514 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:21.940 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:21.942 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:25.361 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: ELL1.
# 2025-10-06 13:42:25.367 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:25.369 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:28.758 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:28.760 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:32.137 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: BT.
# 2025-10-06 13:42:32.142 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:32.144 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:35.531 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:35.533 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:38.938 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: ELL1.
# 2025-10-06 13:42:38.944 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:38.946 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:42.348 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: BT.
# 2025-10-06 13:42:42.354 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:42.356 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:45.722 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:45.724 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:49.111 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: BT.
# 2025-10-06 13:42:49.116 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:49.118 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:52.519 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: DD.
# 2025-10-06 13:42:52.526 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:52.528 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:55.950 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: ELL1.
# 2025-10-06 13:42:55.957 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:55.959 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:59.416 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: BT.
# 2025-10-06 13:42:59.422 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:42:59.424 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:02.831 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:02.833 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:06.232 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: ELL1.
# 2025-10-06 13:43:06.239 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:06.241 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:09.638 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:09.640 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:13.034 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:13.036 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:16.444 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: BT.
# 2025-10-06 13:43:16.450 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:16.452 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:19.976 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:19.977 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:23.395 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: BT.
# 2025-10-06 13:43:23.401 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:23.403 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:26.877 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: BT.
# 2025-10-06 13:43:26.882 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:26.884 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:30.252 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:30.254 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:33.651 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: ELL1.
# 2025-10-06 13:43:33.659 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:33.661 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:37.041 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: BT.
# 2025-10-06 13:43:37.047 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:37.048 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:40.450 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: ELL1.
# 2025-10-06 13:43:40.456 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:40.458 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:43.857 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:43.859 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:47.333 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: DDK.
# 2025-10-06 13:43:47.348 | WARNING  | pint.models.timing_model:validate:426 - PINT does not support 'UNITS TCB' internally. Reading this par file nevertheless because the `allow_tcb` option was given. This `TimingModel` object should not be used for anything except converting to TDB.
# 2025-10-06 13:43:47.349 | WARNING  | pint.models.tcb_conversion:convert_tcb_tdb:133 - Converting this timing model from TCB to TDB. Please note that the TCB to TDB conversion is only approximate and the resulting timing model should be re-fit to get reliable results.
# 2025-10-06 13:43:47.393 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# /opt/venvs/pta/lib/python3.10/site-packages/pint/models/timing_model.py:400: UserWarning: PINT does not support 'DILATEFREQ Y'
#   warn("PINT does not support 'DILATEFREQ Y'")
# /opt/venvs/pta/lib/python3.10/site-packages/pint/models/timing_model.py:403: UserWarning: PINT only supports 'TIMEEPH FB90'
#   warn("PINT only supports 'TIMEEPH FB90'")
# /opt/venvs/pta/lib/python3.10/site-packages/pint/models/timing_model.py:432: UserWarning: START cannot be unfrozen... Setting START.frozen to True
#   warn("START cannot be unfrozen... Setting START.frozen to True")
# /opt/venvs/pta/lib/python3.10/site-packages/pint/models/timing_model.py:435: UserWarning: FINISH cannot be unfrozen... Setting FINISH.frozen to True
#   warn("FINISH cannot be unfrozen... Setting FINISH.frozen to True")
# 2025-10-06 13:43:50.856 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: BT.
# 2025-10-06 13:43:50.870 | WARNING  | pint.models.timing_model:validate:426 - PINT does not support 'UNITS TCB' internally. Reading this par file nevertheless because the `allow_tcb` option was given. This `TimingModel` object should not be used for anything except converting to TDB.
# 2025-10-06 13:43:50.871 | WARNING  | pint.models.tcb_conversion:convert_tcb_tdb:133 - Converting this timing model from TCB to TDB. Please note that the TCB to TDB conversion is only approximate and the resulting timing model should be re-fit to get reliable results.
# 2025-10-06 13:43:50.904 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:54.431 | WARNING  | pint.models.timing_model:validate:426 - PINT does not support 'UNITS TCB' internally. Reading this par file nevertheless because the `allow_tcb` option was given. This `TimingModel` object should not be used for anything except converting to TDB.
# 2025-10-06 13:43:54.431 | WARNING  | pint.models.tcb_conversion:convert_tcb_tdb:133 - Converting this timing model from TCB to TDB. Please note that the TCB to TDB conversion is only approximate and the resulting timing model should be re-fit to get reliable results.
# 2025-10-06 13:43:54.459 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:43:57.964 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: DD.
# 2025-10-06 13:43:57.978 | WARNING  | pint.models.timing_model:validate:426 - PINT does not support 'UNITS TCB' internally. Reading this par file nevertheless because the `allow_tcb` option was given. This `TimingModel` object should not be used for anything except converting to TDB.
# 2025-10-06 13:43:57.979 | WARNING  | pint.models.tcb_conversion:convert_tcb_tdb:133 - Converting this timing model from TCB to TDB. Please note that the TCB to TDB conversion is only approximate and the resulting timing model should be re-fit to get reliable results.
# 2025-10-06 13:43:58.013 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:44:01.547 | WARNING  | pint.models.timing_model:validate:426 - PINT does not support 'UNITS TCB' internally. Reading this par file nevertheless because the `allow_tcb` option was given. This `TimingModel` object should not be used for anything except converting to TDB.
# 2025-10-06 13:44:01.548 | WARNING  | pint.models.tcb_conversion:convert_tcb_tdb:133 - Converting this timing model from TCB to TDB. Please note that the TCB to TDB conversion is only approximate and the resulting timing model should be re-fit to get reliable results.
# 2025-10-06 13:44:01.570 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:44:04.986 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: BT.
# 2025-10-06 13:44:05.000 | WARNING  | pint.models.timing_model:validate:426 - PINT does not support 'UNITS TCB' internally. Reading this par file nevertheless because the `allow_tcb` option was given. This `TimingModel` object should not be used for anything except converting to TDB.
# 2025-10-06 13:44:05.000 | WARNING  | pint.models.tcb_conversion:convert_tcb_tdb:133 - Converting this timing model from TCB to TDB. Please note that the TCB to TDB conversion is only approximate and the resulting timing model should be re-fit to get reliable results.
# 2025-10-06 13:44:05.032 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:44:08.472 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: DD.
# 2025-10-06 13:44:08.486 | WARNING  | pint.models.timing_model:validate:426 - PINT does not support 'UNITS TCB' internally. Reading this par file nevertheless because the `allow_tcb` option was given. This `TimingModel` object should not be used for anything except converting to TDB.
# 2025-10-06 13:44:08.487 | WARNING  | pint.models.tcb_conversion:convert_tcb_tdb:133 - Converting this timing model from TCB to TDB. Please note that the TCB to TDB conversion is only approximate and the resulting timing model should be re-fit to get reliable results.
# 2025-10-06 13:44:08.523 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:44:11.953 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: BT.
# 2025-10-06 13:44:11.968 | WARNING  | pint.models.timing_model:validate:426 - PINT does not support 'UNITS TCB' internally. Reading this par file nevertheless because the `allow_tcb` option was given. This `TimingModel` object should not be used for anything except converting to TDB.
# 2025-10-06 13:44:11.969 | WARNING  | pint.models.tcb_conversion:convert_tcb_tdb:133 - Converting this timing model from TCB to TDB. Please note that the TCB to TDB conversion is only approximate and the resulting timing model should be re-fit to get reliable results.
# 2025-10-06 13:44:12.003 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:44:15.446 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: DDK.
# 2025-10-06 13:44:15.460 | WARNING  | pint.models.timing_model:validate:426 - PINT does not support 'UNITS TCB' internally. Reading this par file nevertheless because the `allow_tcb` option was given. This `TimingModel` object should not be used for anything except converting to TDB.
# 2025-10-06 13:44:15.461 | WARNING  | pint.models.tcb_conversion:convert_tcb_tdb:133 - Converting this timing model from TCB to TDB. Please note that the TCB to TDB conversion is only approximate and the resulting timing model should be re-fit to get reliable results.
# 2025-10-06 13:44:15.495 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:44:19.266 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: DDK.
# 2025-10-06 13:44:19.283 | WARNING  | pint.models.timing_model:validate:426 - PINT does not support 'UNITS TCB' internally. Reading this par file nevertheless because the `allow_tcb` option was given. This `TimingModel` object should not be used for anything except converting to TDB.
# 2025-10-06 13:44:19.284 | WARNING  | pint.models.tcb_conversion:convert_tcb_tdb:133 - Converting this timing model from TCB to TDB. Please note that the TCB to TDB conversion is only approximate and the resulting timing model should be re-fit to get reliable results.
# 2025-10-06 13:44:19.366 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:44:23.002 | WARNING  | pint.models.timing_model:validate:426 - PINT does not support 'UNITS TCB' internally. Reading this par file nevertheless because the `allow_tcb` option was given. This `TimingModel` object should not be used for anything except converting to TDB.
# 2025-10-06 13:44:23.003 | WARNING  | pint.models.tcb_conversion:convert_tcb_tdb:133 - Converting this timing model from TCB to TDB. Please note that the TCB to TDB conversion is only approximate and the resulting timing model should be re-fit to get reliable results.
# 2025-10-06 13:44:23.031 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:44:26.690 | WARNING  | pint.models.timing_model:validate:426 - PINT does not support 'UNITS TCB' internally. Reading this par file nevertheless because the `allow_tcb` option was given. This `TimingModel` object should not be used for anything except converting to TDB.
# 2025-10-06 13:44:26.691 | WARNING  | pint.models.tcb_conversion:convert_tcb_tdb:133 - Converting this timing model from TCB to TDB. Please note that the TCB to TDB conversion is only approximate and the resulting timing model should be re-fit to get reliable results.
# 2025-10-06 13:44:26.717 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:44:30.211 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: DD.
# 2025-10-06 13:44:30.225 | WARNING  | pint.models.timing_model:validate:426 - PINT does not support 'UNITS TCB' internally. Reading this par file nevertheless because the `allow_tcb` option was given. This `TimingModel` object should not be used for anything except converting to TDB.
# 2025-10-06 13:44:30.226 | WARNING  | pint.models.tcb_conversion:convert_tcb_tdb:133 - Converting this timing model from TCB to TDB. Please note that the TCB to TDB conversion is only approximate and the resulting timing model should be re-fit to get reliable results.
# 2025-10-06 13:44:30.263 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:44:33.992 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: DDK.
# 2025-10-06 13:44:34.010 | WARNING  | pint.models.timing_model:validate:426 - PINT does not support 'UNITS TCB' internally. Reading this par file nevertheless because the `allow_tcb` option was given. This `TimingModel` object should not be used for anything except converting to TDB.
# 2025-10-06 13:44:34.011 | WARNING  | pint.models.tcb_conversion:convert_tcb_tdb:133 - Converting this timing model from TCB to TDB. Please note that the TCB to TDB conversion is only approximate and the resulting timing model should be re-fit to get reliable results.
# 2025-10-06 13:44:34.054 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:44:37.782 | WARNING  | pint.models.timing_model:validate:426 - PINT does not support 'UNITS TCB' internally. Reading this par file nevertheless because the `allow_tcb` option was given. This `TimingModel` object should not be used for anything except converting to TDB.
# 2025-10-06 13:44:37.783 | WARNING  | pint.models.tcb_conversion:convert_tcb_tdb:133 - Converting this timing model from TCB to TDB. Please note that the TCB to TDB conversion is only approximate and the resulting timing model should be re-fit to get reliable results.
# 2025-10-06 13:44:37.810 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:44:41.261 | WARNING  | pint.models.timing_model:validate:426 - PINT does not support 'UNITS TCB' internally. Reading this par file nevertheless because the `allow_tcb` option was given. This `TimingModel` object should not be used for anything except converting to TDB.
# 2025-10-06 13:44:41.262 | WARNING  | pint.models.tcb_conversion:convert_tcb_tdb:133 - Converting this timing model from TCB to TDB. Please note that the TCB to TDB conversion is only approximate and the resulting timing model should be re-fit to get reliable results.
# 2025-10-06 13:44:41.285 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:44:44.732 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: BT.
# 2025-10-06 13:44:44.744 | WARNING  | pint.models.timing_model:validate:426 - PINT does not support 'UNITS TCB' internally. Reading this par file nevertheless because the `allow_tcb` option was given. This `TimingModel` object should not be used for anything except converting to TDB.
# 2025-10-06 13:44:44.745 | WARNING  | pint.models.tcb_conversion:convert_tcb_tdb:133 - Converting this timing model from TCB to TDB. Please note that the TCB to TDB conversion is only approximate and the resulting timing model should be re-fit to get reliable results.
# 2025-10-06 13:44:44.778 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:44:48.215 | WARNING  | pint.models.model_builder:choose_binary_model:627 - Found T2 binary model. Gracefully converting T2 to: BT.
# 2025-10-06 13:44:48.228 | WARNING  | pint.models.timing_model:validate:426 - PINT does not support 'UNITS TCB' internally. Reading this par file nevertheless because the `allow_tcb` option was given. This `TimingModel` object should not be used for anything except converting to TDB.
# 2025-10-06 13:44:48.229 | WARNING  | pint.models.tcb_conversion:convert_tcb_tdb:133 - Converting this timing model from TCB to TDB. Please note that the TCB to TDB conversion is only approximate and the resulting timing model should be re-fit to get reliable results.
# 2025-10-06 13:44:48.263 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# /opt/venvs/pta/lib/python3.10/site-packages/pint/models/timing_model.py:406: UserWarning: PINT only supports 'T2CMETHOD IAU2000B'
#   warn("PINT only supports 'T2CMETHOD IAU2000B'")
# 2025-10-06 13:44:51.867 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:44:55.426 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:44:58.879 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:45:02.350 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:45:05.794 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:45:09.263 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:45:13.283 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:45:16.883 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:45:20.457 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:45:24.199 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:45:27.633 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:45:31.290 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:45:34.736 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:45:38.162 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:45:41.620 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:45:45.139 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# /opt/venvs/pta/lib/python3.10/site-packages/pint/models/model_builder.py:225: UserWarning: Unrecognized parfile line 'PAASCNODE 81.08'
#   warnings.warn(f"Unrecognized parfile line '{p_line}'", UserWarning)
# 2025-10-06 13:45:48.634 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:45:52.299 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:45:55.730 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:45:59.149 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:46:02.573 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:46:05.947 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:46:09.351 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:46:12.833 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:46:16.423 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:46:19.849 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:46:23.446 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:46:26.876 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:46:30.301 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:46:33.732 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:46:37.242 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:46:40.882 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:46:44.343 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:46:47.863 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:46:51.359 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:46:54.983 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# 2025-10-06 13:46:58.625 | WARNING  | pint.models.model_builder:__call__:229 - UNITS is not specified. Assuming TDB...
# Found 47 pulsars: ['J0030+0451', 'J0034-0534', 'J0218+4232', 'J0610-2100', 'J0613-0200', 'J0621+1002', 'J0751+1807', 'J0900-3144', 'J1012+5307', 'J1022+1001', 'J1024-0719', 'J1455-3330', 'J1600-3053', 'J1640+2224', 'J1643-1224', 'J1713+0747', 'J1721-2457', 'J1730-2304', 'J1738+0333', 'J1744-1134', 'J1751-2857', 'J1801-1417', 'J1802-2124', 'J1804-2717', 'J1843-1113', 'J1853+1303', 'J1857+0943', 'J1909-3744', 'J1910+1256', 'J1911+1347', 'J1911-1114', 'J1918-0642', 'J1939+2134', 'J1955+2908', 'J2010-1323', 'J2019+2425', 'J2033+1734', 'J2124-3358', 'J2145-0750', 'J2229+2643', 'J2317+1439', 'J2322+2057', 'J0437-4715', 'J0711-6830', 'J1045-4509', 'J1603-7202', 'J2129-5721']

# %%
if not file_data_with_files:
    print("\nNo PTAs have files - this might happen in test environments")
    print("In a real environment, you would have actual par/tim files")
else:
    print(f"\nUsing PTAs with files: {list(file_data_with_files.keys())}")
    
    # Create MetaPulsar factory
    factory = MetaPulsarFactory()
    
    # Create MetaPulsar with consistent strategy (preferred for Enterprise)
    print("\nCreating MetaPulsar with consistent strategy...")
    reference_pta = list(file_data_with_files.keys())[0]
    
    metapulsar = factory.create_metapulsar(
        file_data_with_files,
        combination_strategy="consistent",
        reference_pta=reference_pta
    )
    
    print("✅ MetaPulsar created successfully!")
    print(f"   Strategy: {metapulsar.combination_strategy}")
    print(f"   Reference PTA: {reference_pta}")
    print(f"   Number of PTAs: {len(metapulsar.pulsars)}")
    print(f"   PTA names: {list(metapulsar.pulsars.keys())}")
    
    # Show Enterprise-ready data structure
    print("\nEnterprise-ready data structure:")
    print(f"   MetaPulsar object: {type(metapulsar).__name__}")
    print(f"   Pulsars: {len(metapulsar.pulsars)}")
    print(f"   Combination strategy: {metapulsar.combination_strategy}")
    print("   Ready for Enterprise integration: ✅")

# %% [markdown]
# ## 2. Create Staggered Selection for Enterprise
#
# Staggered selection is a key feature for Enterprise integration, allowing you to select data based on multiple criteria.

# %%
# Create staggered selection function for Enterprise
print("Creating staggered selection function...")

# Create staggered selection function
selection_func = create_staggered_selection(
    name="telescope_backend_selection",
    flag_criteria={
        "telescope": None,  # Primary flag
        ("backend", "freq_band"): None,  # Fallback flags
    },
    freq_range=(50, 2000)  # Frequency range
)

print(f"✅ Staggered selection function created: {selection_func.__name__}")
print(f"   Function type: {type(selection_func).__name__}")
print(f"   Callable: {callable(selection_func)}")

# Show how to use the selection function
print("\nUsage example:")
print("   # In Enterprise, you would use this function like:")
print("   # selection = selection_func(timing_data)")
print("   # This would select data based on telescope, backend, and frequency criteria")

# %% [markdown]
# ## 3. Enterprise Integration Workflow
#
# Here's how to integrate MetaPulsar with Enterprise for gravitational wave analysis.

# %%
# Demonstrate Enterprise integration workflow
print("=== Enterprise Integration Workflow ===")
print()
print("1. MetaPulsar Data Preparation:")
print("   ✅ MetaPulsar object created with consistent strategy")
print("   ✅ Data aligned to reference PTA for astrophysical consistency")
print("   ✅ Ready for Enterprise model integration")
print()
print("2. Staggered Selection Setup:")
print("   ✅ Selection function created for data filtering")
print("   ✅ Criteria defined for telescope, backend, and frequency")
print("   ✅ Frequency range specified: 50-2000 MHz")
print()
print("3. Enterprise Integration Steps:")
print("   📋 Import Enterprise modules")
print("   📋 Create Enterprise PTA object from MetaPulsar data")
print("   📋 Apply staggered selection to timing data")
print("   📋 Set up gravitational wave models")
print("   📋 Run MCMC or other analysis methods")
print()
print("4. Example Enterprise Code Structure:")
print("   ```python")
print("   import enterprise")
print("   from enterprise.pulsar import Pulsar")
print("   ")
print("   # Convert MetaPulsar to Enterprise format")
print("   enterprise_pta = Pulsar(metapulsar_data)")
print("   ")
print("   # Apply staggered selection")
print("   selected_data = selection_func(enterprise_pta)")
print("   ")
print("   # Set up models and run analysis")
print("   # ... (Enterprise-specific code)")
print("   ```")
print()
print("5. Benefits of MetaPulsar + Enterprise:")
print("   🚀 Unified multi-PTA data handling")
print("   🚀 Astrophysical consistency across PTAs")
print("   🚀 Flexible data selection strategies")
print("   🚀 Seamless integration with Enterprise models")
print("   🚀 Enhanced gravitational wave detection capabilities")

# %% [markdown]
# ## 4. Summary
#
# In this tutorial, you learned:
#
# 1. **MetaPulsar Preparation**: How to prepare MetaPulsar data for Enterprise integration
# 2. **Staggered Selection**: How to create selection functions for data filtering
# 3. **Integration Workflow**: How to integrate MetaPulsar with Enterprise
# 4. **Best Practices**: How to structure your Enterprise analysis with MetaPulsar
#
# ### Key Concepts
#
# - **Consistent Strategy**: Preferred for Enterprise integration due to astrophysical consistency
# - **Staggered Selection**: Flexible data selection based on multiple criteria
# - **Enterprise PTA**: Conversion of MetaPulsar data to Enterprise format
# - **Gravitational Wave Analysis**: Enhanced detection capabilities with multi-PTA data
#
# ### Next Steps
#
# - **Advanced Workflows**: Learn about advanced use cases (see `04_advanced_workflows.ipynb`)
# - **Real Data Analysis**: Apply these concepts to actual PTA data
# - **Enterprise Models**: Explore Enterprise's gravitational wave models
#
# ### Key Takeaways
#
# - MetaPulsar provides a solid foundation for Enterprise integration
# - Staggered selection offers flexible data filtering capabilities
# - Consistent strategy ensures astrophysical validity across PTAs
# - The combination enhances gravitational wave detection sensitivity

# %% [markdown]
# ur packa
