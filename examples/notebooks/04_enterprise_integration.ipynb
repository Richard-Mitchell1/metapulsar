# %% [markdown]
# # MetaPulsar Enterprise Integration Tutorial
#
# This notebook demonstrates how to integrate MetaPulsar with the Enterprise framework for gravitational wave analysis.
#
# ## Learning Objectives
# - Understand Enterprise integration concepts
# - Learn how to use staggered selection utilities
# - Explore MetaPulsar data preparation for Enterprise
# - Handle Enterprise-specific data requirements

# %%
from metapulsar import FileDiscoveryService, MetaPulsarFactory, create_staggered_selection

from loguru import logger

# Set global loguru level
logger.remove()
logger.add(lambda msg: print(msg, end=""), level="WARNING")


print("MetaPulsar Enterprise Integration imported successfully!")
# Out:
# MetaPulsar Enterprise Integration imported successfully!

# %% [markdown]
# ## 1. Prepare MetaPulsar Data
#
# First, let's create MetaPulsar data that can be used with Enterprise.

# %%
# Create file discovery service with working directory
# Note: We need to specify the working directory because the notebook runs from
# /workspaces/metapulsar/examples/notebooks/ but the data is in /workspaces/metapulsar/data/
discovery = FileDiscoveryService(working_dir="/workspaces/metapulsar")

# Discover files for specific PTAs
# Note: Using available PTAs that have data
pta_names = ["epta_dr1_v2_2", "ppta_dr2", "nanograv_9y"]
file_data = discovery.discover_all_files_in_ptas(pta_names)

print("File discovery results:")
for pta_name, files in file_data.items():
    print(f"  {pta_name}: {len(files)} file pairs")
# Out:
# 2025-10-06 13:22:03.177 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J0034-0534/J0034-0534_all.tim: invalid literal for int() with base 10: 'TOAS'
# 2025-10-06 13:22:03.183 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J0218+4232/J0218+4232_all.tim: invalid literal for int() with base 10: '0 55058'
# 2025-10-06 13:22:03.185 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J0610-2100/J0610-2100_all.tim: invalid literal for int() with base 10: '0 55372'
# 2025-10-06 13:22:03.192 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J0613-0200/J0613-0200_all.tim: invalid literal for int() with base 10: '0 55054'
# 2025-10-06 13:22:03.198 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J0621+1002/J0621+1002_all.tim: invalid literal for int() with base 10: '0 55062'
# 2025-10-06 13:22:03.206 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J0751+1807/J0751+1807_all.tim: invalid literal for int() with base 10: '0 55054'
# 2025-10-06 13:22:03.211 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J0900-3144/J0900-3144_all.tim: invalid literal for int() with base 10: '0 55073'
# 2025-10-06 13:22:03.215 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1012+5307/J1012+5307_all.tim: invalid literal for int() with base 10: '0 55122'
# 2025-10-06 13:22:03.226 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1022+1001/J1022+1001_all.tim: invalid literal for int() with base 10: '0 55065'
# 2025-10-06 13:22:03.236 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1024-0719/J1024-0719_all.tim: invalid literal for int() with base 10: '0 55059'
# 2025-10-06 13:22:03.238 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1455-3330/J1455-3330_all.tim: invalid literal for int() with base 10: '0 55114'
# 2025-10-06 13:22:03.355 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1640+2224/J1640+2224_all.tim: invalid literal for int() with base 10: '0 55057'
# 2025-10-06 13:22:03.359 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1643-1224/J1643-1224_all.tim: invalid literal for int() with base 10: '0 55069'
# 2025-10-06 13:22:03.704 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1730-2304/J1730-2304_all.tim: invalid literal for int() with base 10: '0 55073'
# 2025-10-06 13:22:03.756 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1738+0333/J1738+0333_all.tim: list index out of range
# 2025-10-06 13:22:03.785 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1744-1134/J1744-1134_all.tim: could not convert string to float: 'c015621.align.pazr.30min'
# 2025-10-06 13:22:03.825 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1801-1417/J1801-1417_all.tim: invalid literal for int() with base 10: '0 55074'
# 2025-10-06 13:22:03.942 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1804-2717/J1804-2717_all.tim: invalid literal for int() with base 10: '0 54854'
# 2025-10-06 13:22:03.979 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1843-1113/J1843-1113_all.tim: invalid literal for int() with base 10: '0 55059'
# 2025-10-06 13:22:03.982 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1853+1303/J1853+1303_all.tim: invalid literal for int() with base 10: '0 55066'
# 2025-10-06 13:22:04.177 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1910+1256/J1910+1256_all.tim: invalid literal for int() with base 10: '0 54868'
# 2025-10-06 13:22:04.194 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1911+1347/J1911+1347_all.tim: list index out of range
# 2025-10-06 13:22:04.233 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1918-0642/J1918-0642_all.tim: invalid literal for int() with base 10: '0 55048'
# 2025-10-06 13:22:04.285 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J1939+2134/J1939+2134_all.tim: could not convert string to float: 'c028084.pazr.iter.30min'
# 2025-10-06 13:22:04.335 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J2010-1323/J2010-1323_all.tim: invalid literal for int() with base 10: '0 55060'
# 2025-10-06 13:22:04.337 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J2019+2425/J2019+2425_all.tim: invalid literal for int() with base 10: '0 55053'
# 2025-10-06 13:22:04.342 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J2033+1734/J2033+1734_all.tim: invalid literal for int() with base 10: '0 55059'
# 2025-10-06 13:22:04.465 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J2145-0750/J2145-0750_all.tim: invalid literal for int() with base 10: '0 55037'
# 2025-10-06 13:22:04.470 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J2229+2643/J2229+2643_all.tim: invalid literal for int() with base 10: '0 55063'
# 2025-10-06 13:22:04.475 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J2317+1439/J2317+1439_all.tim: invalid literal for int() with base 10: '0 55056'
# 2025-10-06 13:22:04.480 | WARNING  | metapulsar.tim_file_analyzer:calculate_timespan:58 - PINT parsing failed for /workspaces/metapulsar/data/ipta-dr2/EPTA_v2.2/J2322+2057/J2322+2057_all.tim: invalid literal for int() with base 10: '0 55065'
# File discovery results:
#   epta_dr1_v2_2: 42 file pairs
#   ppta_dr2: 18 file pairs
#   nanograv_9y: 37 file pairs

# %%
# Filter out PTAs with no files
file_data_with_files = {pta: files for pta, files in file_data.items() if files}

if not file_data_with_files:
    print("\nNo PTAs have files - this might happen in test environments")
    print("In a real environment, you would have actual par/tim files")
else:
    print(f"\nUsing PTAs with files: {list(file_data_with_files.keys())}")
    
    # Create MetaPulsar factory
    factory = MetaPulsarFactory()
    
    # Create MetaPulsar with consistent strategy (preferred for Enterprise)
    print("\nCreating MetaPulsar with consistent strategy...")
    reference_pta = list(file_data_with_files.keys())[0]
    
    metapulsar = factory.create_metapulsar(
        file_data_with_files,
        combination_strategy="consistent",
        reference_pta=reference_pta
    )
    
    print("✅ MetaPulsar created successfully!")
    print(f"   Strategy: {metapulsar.combination_strategy}")
    print(f"   Reference PTA: {reference_pta}")
    print(f"   Number of PTAs: {len(metapulsar.pulsars)}")
    print(f"   PTA names: {list(metapulsar.pulsars.keys())}")
    
    # Show Enterprise-ready data structure
    print("\nEnterprise-ready data structure:")
    print(f"   MetaPulsar object: {type(metapulsar).__name__}")
    print(f"   Pulsars: {len(metapulsar.pulsars)}")
    print(f"   Combination strategy: {metapulsar.combination_strategy}")
    print("   Ready for Enterprise integration: ✅")
# Out:
# Using PTAs with files: ['epta_dr1_v2_2', 'ppta_dr2', 'nanograv_9y']
#
# Creating MetaPulsar with consistent strategy...
# Tempo2 conversion failed for PTA ppta_dr2: [Errno 13] Permission denied: 'tempo2'
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# File /workspaces/metapulsar/src/metapulsar/parameter_manager.py:205, in ParameterManager._convert_mixed_units(self, file_units, parfile_contents)
#     204 try:
# --> 205     converted_content = self._convert_tempo2_to_tdb(parfile_content)
#     206     converted_parfiles[pta_name] = converted_content
#
# File /workspaces/metapulsar/src/metapulsar/parameter_manager.py:692, in ParameterManager._convert_tempo2_to_tdb(self, parfile_content)
#     690 try:
#     691     # Run tempo2 transform command
# --> 692     subprocess.run(
#     693         [
#     694             "tempo2",
#     695             "-gr",
#     696             "transform",
#     697             input_file.name,
#     698             output_file.name,
#     699             "tdb",
#     700         ],
#     701         check=True,
#     702         capture_output=True,
#     703         text=True,
#     704     )
#     706     # Read converted content
#
# File /usr/lib/python3.10/subprocess.py:503, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     501     kwargs['stderr'] = PIPE
# --> 503 with Popen(*popenargs, **kwargs) as process:
#     504     try:
#
# File /usr/lib/python3.10/subprocess.py:971, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize)
#     968             self.stderr = io.TextIOWrapper(self.stderr,
#     969                     encoding=encoding, errors=errors)
# --> 971     self._execute_child(args, executable, preexec_fn, close_fds,
#     972                         pass_fds, cwd, env,
#     973                         startupinfo, creationflags, shell,
#     974                         p2cread, p2cwrite,
#     975                         c2pread, c2pwrite,
#     976                         errread, errwrite,
#     977                         restore_signals,
#     978                         gid, gids, uid, umask,
#     979                         start_new_session)
#     980 except:
#     981     # Cleanup if the child failed starting.
#
# File /usr/lib/python3.10/subprocess.py:1863, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, gid, gids, uid, umask, start_new_session)
#    1862         err_msg = os.strerror(errno_num)
# -> 1863     raise child_exception_type(errno_num, err_msg, err_filename)
#    1864 raise child_exception_type(err_msg)
#
# PermissionError: [Errno 13] Permission denied: 'tempo2'
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 17
#      14 print("\nCreating MetaPulsar with consistent strategy...")
#      15 reference_pta = list(file_data_with_files.keys())[0]
# ---> 17 metapulsar = factory.create_metapulsar(
#      18     file_data_with_files,
#      19     combination_strategy="consistent",
#      20     reference_pta=reference_pta
#      21 )
#      23 print(f"✅ MetaPulsar created successfully!")
#      24 print(f"   Strategy: {metapulsar.combination_strategy}")
#
# File /workspaces/metapulsar/src/metapulsar/metapulsar_factory.py:91, in MetaPulsarFactory.create_metapulsar(self, file_data, combination_strategy, reference_pta, combine_components, add_dm_derivatives)
#      70 """Create MetaPulsar using specified combination strategy.
#      71
#      72 Args:
#    (...)
#      87     RuntimeError: If Enterprise Pulsar creation fails
#      88 """
#      89 self.logger.info(f"Creating MetaPulsar using {combination_strategy} strategy")
# ---> 91 return self.create_metapulsar_from_file_data(
#      92     file_data,
#      93     combination_strategy,
#      94     reference_pta,
#      95     combine_components,
#      96     add_dm_derivatives,
#      97 )
#
# File /workspaces/metapulsar/src/metapulsar/metapulsar_factory.py:157, in MetaPulsarFactory.create_metapulsar_from_file_data(self, file_data, combination_strategy, reference_pta, combine_components, add_dm_derivatives)
#     149 parameter_manager = ParameterManager(
#     150     file_data=single_file_data,
#     151     reference_pta=reference_pta,
#     152     combine_components=combine_components,
#     153     add_dm_derivatives=add_dm_derivatives,
#     154 )
#     156 # Make par files consistent
# --> 157 consistent_parfiles = parameter_manager.make_parfiles_consistent()
#     159 # Update file_pairs with consistent par files
#     160 file_pairs = {
#     161     pta: (consistent_parfiles[pta], single_file_data[pta]["tim"])
#     162     for pta in single_file_data.keys()
#     163     if pta in consistent_parfiles
#     164 }
#
# File /workspaces/metapulsar/src/metapulsar/parameter_manager.py:94, in ParameterManager.make_parfiles_consistent(self)
#      91 parfile_dicts = self._parse_parfiles()
#      93 # 2. Convert units if needed
# ---> 94 converted_parfiles = self._convert_units_if_needed(parfile_dicts)
#      96 # 3. Make parameters consistent
#      97 consistent_parfiles = self._make_parameters_consistent(converted_parfiles)
#
# File /workspaces/metapulsar/src/metapulsar/parameter_manager.py:148, in ParameterManager._convert_units_if_needed(self, parfile_dicts)
#     144 # Mixed units detected, conversion needed
#     145 self.logger.info(
#     146     f"Mixed units detected: {unique_units}. Converting TCB files to TDB."
#     147 )
# --> 148 return self._convert_mixed_units(file_units, parfile_contents)
#
# File /workspaces/metapulsar/src/metapulsar/parameter_manager.py:212, in ParameterManager._convert_mixed_units(self, file_units, parfile_contents)
#     208             except Exception as e:
#     209                 self.logger.error(
#     210                     f"Tempo2 conversion failed for PTA {pta_name}: {e}"
#     211                 )
# --> 212                 raise RuntimeError(
#     213                     f"Tempo2 unit conversion failed for PTA {pta_name}"
#     214                 ) from e
#     216 return converted_parfiles
#
# RuntimeError: Tempo2 unit conversion failed for PTA ppta_dr2

# %% [markdown]
# ## 2. Create Staggered Selection for Enterprise
#
# Staggered selection is a key feature for Enterprise integration, allowing you to select data based on multiple criteria.

# %%
# Create staggered selection function for Enterprise
print("Creating staggered selection function...")

# Create staggered selection function
selection_func = create_staggered_selection(
    name="telescope_backend_selection",
    flag_criteria={
        "telescope": None,  # Primary flag
        ("backend", "freq_band"): None,  # Fallback flags
    },
    freq_range=(50, 2000)  # Frequency range
)

print(f"✅ Staggered selection function created: {selection_func.__name__}")
print(f"   Function type: {type(selection_func).__name__}")
print(f"   Callable: {callable(selection_func)}")

# Show how to use the selection function
print("\nUsage example:")
print("   # In Enterprise, you would use this function like:")
print("   # selection = selection_func(timing_data)")
print("   # This would select data based on telescope, backend, and frequency criteria")

# %% [markdown]
# ## 3. Enterprise Integration Workflow
#
# Here's how to integrate MetaPulsar with Enterprise for gravitational wave analysis.

# %%
# Demonstrate Enterprise integration workflow
print("=== Enterprise Integration Workflow ===")
print()
print("1. MetaPulsar Data Preparation:")
print("   ✅ MetaPulsar object created with consistent strategy")
print("   ✅ Data aligned to reference PTA for astrophysical consistency")
print("   ✅ Ready for Enterprise model integration")
print()
print("2. Staggered Selection Setup:")
print("   ✅ Selection function created for data filtering")
print("   ✅ Criteria defined for telescope, backend, and frequency")
print("   ✅ Frequency range specified: 50-2000 MHz")
print()
print("3. Enterprise Integration Steps:")
print("   📋 Import Enterprise modules")
print("   📋 Create Enterprise PTA object from MetaPulsar data")
print("   📋 Apply staggered selection to timing data")
print("   📋 Set up gravitational wave models")
print("   📋 Run MCMC or other analysis methods")
print()
print("4. Example Enterprise Code Structure:")
print("   ```python")
print("   import enterprise")
print("   from enterprise.pulsar import Pulsar")
print("   ")
print("   # Convert MetaPulsar to Enterprise format")
print("   enterprise_pta = Pulsar(metapulsar_data)")
print("   ")
print("   # Apply staggered selection")
print("   selected_data = selection_func(enterprise_pta)")
print("   ")
print("   # Set up models and run analysis")
print("   # ... (Enterprise-specific code)")
print("   ```")
print()
print("5. Benefits of MetaPulsar + Enterprise:")
print("   🚀 Unified multi-PTA data handling")
print("   🚀 Astrophysical consistency across PTAs")
print("   🚀 Flexible data selection strategies")
print("   🚀 Seamless integration with Enterprise models")
print("   🚀 Enhanced gravitational wave detection capabilities")

# %% [markdown]
# ## 4. Summary
#
# In this tutorial, you learned:
#
# 1. **MetaPulsar Preparation**: How to prepare MetaPulsar data for Enterprise integration
# 2. **Staggered Selection**: How to create selection functions for data filtering
# 3. **Integration Workflow**: How to integrate MetaPulsar with Enterprise
# 4. **Best Practices**: How to structure your Enterprise analysis with MetaPulsar
#
# ### Key Concepts
#
# - **Consistent Strategy**: Preferred for Enterprise integration due to astrophysical consistency
# - **Staggered Selection**: Flexible data selection based on multiple criteria
# - **Enterprise PTA**: Conversion of MetaPulsar data to Enterprise format
# - **Gravitational Wave Analysis**: Enhanced detection capabilities with multi-PTA data
#
# ### Next Steps
#
# - **Advanced Workflows**: Learn about advanced use cases (see `04_advanced_workflows.ipynb`)
# - **Real Data Analysis**: Apply these concepts to actual PTA data
# - **Enterprise Models**: Explore Enterprise's gravitational wave models
#
# ### Key Takeaways
#
# - MetaPulsar provides a solid foundation for Enterprise integration
# - Staggered selection offers flexible data filtering capabilities
# - Consistent strategy ensures astrophysical validity across PTAs
# - The combination enhances gravitational wave detection sensitivity

# %% [markdown]
# ur packa
